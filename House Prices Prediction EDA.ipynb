# %% [markdown]
# # Importing The Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize']=10,5

# %% [markdown]
# ---

# %% [markdown]
# # Loading and Checking the Data

# %%
data=pd.read_csv("kc_house_data .csv")

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.shape
# Out:
# (21613, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# There is no null data, and that is good.

# %%
No_Bedrooms = (data["bedrooms"]== 0).sum()
No_Bathrooms = (data["bathrooms"]== 0).sum()
print("Number of zeros bedrooms=",No_Bedrooms)
print("Number of zeros bedrooms=",No_Bathrooms)
# Out:
# Number of zeros bedrooms= 13
# Number of zeros bedrooms= 10

# %% [markdown]
# ___

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# The 'id','zipcode' columns will be droped because each property has its unique id, and zipcode.

# %%
data.drop("id",axis=1,inplace=True)
data.drop("zipcode",axis=1,inplace=True)

# %%
data.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0         3       1.00         1180      5650
# 1  20141209T000000  538000.0         3       2.25         2570      7242
# 2  20150225T000000  180000.0         2       1.00          770     10000
# 3  20141209T000000  604000.0         4       3.00         1960      5000
# 4  20150218T000000  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated      lat     long  sqft_living15  sqft_lot15
# ...

# %% [markdown]
# "time" column is splitted into three related columns: "year", "month", "day", after that "time" column is deleted.

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
# earliest date
data['date'].min()
# Out:
# Timestamp('2014-05-02 00:00:00')

# %%
# latest date
data['date'].max()
# Out:
# Timestamp('2015-05-27 00:00:00')

# %%
data['date'] = pd.to_datetime(data['date'])
data['year'] = data['date'].dt.year
data['month'] = data['date'].dt.month
data['day'] = data['date'].dt.day
data.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
data = data.drop("date",axis=1)
data.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month  day
# ...

# %% [markdown]
# # Data Exploration

# %% [markdown]
# This section will study the hypotheses that related to the price

# %%
# Hypothesis 1: increasing number of bedrooms would increase the price 
sns.barplot(data=data, x="bedrooms", y="price")
plt.title("Relationship between number of bedrooms & average price ")
# Out:
# Text(0.5, 1.0, 'Relationship between number of bedrooms & average price ')

# %% [markdown]
# The graph shows a relationship between the number of bedrooms and the average price, but we need another chart to understand the relationship more clearly.

# %%
sns.lineplot(data=data, x="bedrooms", y="price",err_style=None)
plt.title("Relationship between number of bedrooms & price ")
# Out:
# Text(0.5, 1.0, 'Relationship between number of bedrooms & price ')

# %% [markdown]
# Line graph doesn't show a clear relationship between the number of bedrooms and the average price. For that, a box plot chart has been chosen to take a clear vision on the relationship.

# %%
sns.boxplot(data=data, x="bedrooms", y="price",sym="")
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %% [markdown]
# The graph shows that there is a positive relationship between bedrooms & price. (more bedrooms means higher price, which is confirming the hypothesis)

# %% [markdown]
# ___

# %%
# Hypothisis 2: increasing number of bathrooms would increase the price 
sns.boxplot(data=data, x="bathrooms", y="price",sym="")
plt.title("Relationship between number of bathrooms & price ")
# Out:
# Text(0.5, 1.0, 'Relationship between number of bathrooms & price ')

# %% [markdown]
# The graph shows that there is a positive relationship between bathrooms & price. (more bathrooms means higher price, which is confirming the hypothesis)

# %% [markdown]
# ___

# %%
# Hypothesis 3: increasing sqft_living area would increase the price 
sns.lineplot(data=data, x="sqft_living", y="price",err_style=None)
plt.title("Relationship between sqft_living area & price ")
# Out:
# Text(0.5, 1.0, 'Relationship between sqft_living area & price ')

# %% [markdown]
# The graph shows that there is a positive relationship between sqft_living area & price. (more sqft_living area means higher price, which is confirming the hypothesis)

# %% [markdown]
# ___

# %%
# Hypothesis 4: increasing sqft_lot area would increase the price 
sns.lineplot(data=data, x="sqft_lot", y="price",err_style=None)
plt.title("Relationship between sqft_lot area & price ")
# Out:
# Text(0.5, 1.0, 'Relationship between sqft_lot area & price ')

# %% [markdown]
# The graph shows that the relationship between sqft_lot & price is not clear.

# %% [markdown]
# ___

# %%
# Hypothesis 5: increasing number of floors would increase the price 
sns.boxplot(data=data, x="floors", y="price",sym="")
plt.title("Relationship between number of floors & price ")
# Out:
# Text(0.5, 1.0, 'Relationship between number of floors & price ')

# %% [markdown]
# The grph doesn't show any relationship between number of floors and the price (increasing number of floors would not increase the price, wich rejects hypothesis

# %% [markdown]
# ___

# %%
# Hypothesis 6: Houses nearest waterfront have a higher price
sns.catplot(data=data, x="waterfront", y="price", kind="box",sym="")
plt.title("Relationship between waterfront & price ")
# Out:
# Text(0.5, 1.0, 'Relationship between waterfront & price ')

# %% [markdown]
# The graph  shows that there is a relationship between having waterfront and the price (houses nearest waterfront have a higher price, wich is confirming the hypothesis)

# %% [markdown]
# ___

# %%
# Hypothesis 7: higher view ranking have a higher price
sns.catplot(data=data, x="view", y="price", kind="box",sym="")
plt.title("Relationship between view rank & price ")
# Out:
# Text(0.5, 1.0, 'Relationship between view rank & price ')

# %% [markdown]
# The graph shows that there is a slight positive relationship between view rank and the price (higher view rate means higher price, wich is confirming the hypothesis)

# %% [markdown]
# ___

# %%
# Hypothesis 8: increasing condition ranking would increase the price 
sns.boxplot(data=data, x="condition", y="price", sym="")
plt.title("Relationship between condition rank & price ")
# Out:
# Text(0.5, 1.0, 'Relationship between condition rank & price ')

# %% [markdown]
# The graph shows that there is no relationship between condition rank and the price (higher condition rank doesn't mean a higher price, wich rejects the hypothesis)

# %% [markdown]
# ___

# %%
# Hypothesis 9: increasing grade ranke would increase the price 
sns.boxplot(data=data, x="grade", y="price",sym="")
plt.title("Relationship between grade rank & price ")
# Out:
# Text(0.5, 1.0, 'Relationship between grade rank & price ')

# %% [markdown]
# The graph shows that there is a relationship between grade rank and the price (higher grade rank mean a higher price, wich is confirming the hypothesis)

# %% [markdown]
# ___

# %%
# Hypothesis 10: increasing sqft_above area would increase the price 
sns.lineplot(data=data, x="sqft_above", y="price",err_style=None)
plt.title("Relationship between sqft_above area & price ")
# Out:
# Text(0.5, 1.0, 'Relationship between sqft_above area & price ')

# %% [markdown]
# The graph shows that there is a relationship between sqft_bove area and the price (higher sqft_bove area mean a higher price, wich is confirming the hypothesis)

# %% [markdown]
# ___

# %%
# Hypothesis 11: increasing sqft_basement area would increase the price 
sns.lineplot(data=data, x="sqft_basement", y="price",err_style=None)
plt.title("Relationship between sqft_basement area & price ")
# Out:
# Text(0.5, 1.0, 'Relationship between sqft_basement area & price ')

# %% [markdown]
# The graph shows that there is a relationship between sqft_basement area and the price (higher sqft_basement area means a higher price, wich is confirming the hypothesis)

# %% [markdown]
# ___

# %%
# Hypothesis 12: increasing yr_built would increase the price 
sns.lineplot(data=data, x="yr_built", y="price",err_style=None)
plt.title("Relationship between yr_built & price ")
# Out:
# Text(0.5, 1.0, 'Relationship between yr_built & price ')

# %% [markdown]
# The graph shows that there is a slight relationship between yr_built and the price (people are typically willing to spend more for newer homes, but not actuly accurate, so I will reject the hypothesis)

# %% [markdown]
# ___

# %% [markdown]
# ___

# %%
# Hypothisis 13: increasing sqft_living15 area would increase the price 
sns.lineplot(data=data, x="sqft_living15", y="price",err_style=None)
plt.title("Relationship between sqft_living15 & price ")
# Out:
# Text(0.5, 1.0, 'Relationship between sqft_living15 & price ')

# %% [markdown]
# The graph shows that there is a relationship between sqft_living15 and the price (higher sqft_living15 areas have a higher price, wich is conforming the hypothesis)

# %% [markdown]
# ___

# %%
sns.scatterplot(x="long",y="lat",data=data,hue="price", palette="ocean_r")
plt.title("Relationship between long & lat on price ")
# Out:
# Text(0.5, 1.0, 'Relationship between long & lat on price ')

# %% [markdown]
# The graph shows that there is a relationship between latitude and the price, and there is no relationship between longitude and the price (heading North will increase the price.On the other hand, moving East or West would not increase the price)

# %%
sns.lineplot(data=data, x="month", y="price",hue="year" ,palette="Set1",err_style=None)
plt.title("Relationship between month & price ")
# Out:
# Text(0.5, 1.0, 'Relationship between month & price ')

# %% [markdown]
# The graph shows that there is a relationship between months and price. starting from May 2014, price started to go down
# till Feb 2015, after that it started to go up.

# %% [markdown]
# ___

# %% [markdown]
# # Feature Extraction

# %%
cor = data.corr()
plt.figure(figsize=(20,15))
sns.heatmap(cor, annot=True, cmap=plt.cm.BrBG)
plt.title("Correlation matrix among features")
plt.show()

# %%
data.corr()["price"].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# year             0.003576
# month           -0.010081
# day             -0.014670
# Name: price, dtype: float64

# %% [markdown]
# The graph shows the most features that have a strong positive relationship with the price: sqft_living ,grade ,sqft_above, sqft_living15, bathrooms.
